# %%
from jqdata import *
from jqfactor import *

# %%
from jqdata import *
from jqfactor import *

#第一次下载部分股票信息
# stock_list = ['601899.XSHG',
#               '600519.XSHG','601169.XSHG','002202.XSHE','601618.XSHG','002236.XSHE','601088.XSHG','000725.XSHE',
#               '603993.XSHG','000001.XSHE','600196.XSHG','601288.XSHG','600332.XSHG','601800.XSHG','002142.XSHE',
#               '000568.XSHE','601989.XSHG','600406.XSHG','000858.XSHE','002007.XSHE','600009.XSHG','000876.XSHE',
#               '601328.XSHG','600585.XSHG','600028.XSHG','600893.XSHG','600309.XSHG','601377.XSHG','601998.XSHG',
#               '000157.XSHE','601006.XSHG','601628.XSHG','600276.XSHG','601009.XSHG','600048.XSHG','600547.XSHG',
#               '600383.XSHG','601186.XSHG','601390.XSHG','600000.XSHG','600837.XSHG','601888.XSHG','000002.XSHE',
#               '600588.XSHG','600660.XSHG','600104.XSHG','000425.XSHE','600111.XSHG','000768.XSHE','600741.XSHG',
#               '601988.XSHG','000538.XSHE','601766.XSHG','600900.XSHG','600050.XSHG','601668.XSHG','000063.XSHE',
#               '600015.XSHG','601336.XSHG','600016.XSHG','600795.XSHG','601601.XSHG','601901.XSHG','601111.XSHG',
#               '002304.XSHE','601818.XSHG','002594.XSHE','601166.XSHG','601318.XSHG','002415.XSHE','601939.XSHG',
#               '601688.XSHG','600690.XSHG','000625.XSHE','002230.XSHE','600019.XSHG','600085.XSHG','000333.XSHE',
#               '000338.XSHE','600036.XSHG','601669.XSHG','000069.XSHE','600010.XSHG','002241.XSHE','600030.XSHG',
#               '000963.XSHE','600018.XSHG','600115.XSHG','601857.XSHG','600029.XSHG','600999.XSHG','601398.XSHG',
#               '600886.XSHG','601600.XSHG','000651.XSHE','600887.XSHG','601633.XSHG','600031.XSHG','000776.XSHE',
#               '000100.XSHE','600362.XSHG','000895.XSHE'
#              ]


#第二次下载三个指数信息
stock_list = ['000300.XSHG','000001.XSHG','399001.XSHE']


df = get_price(stock_list,start_date='2014-1-2',end_date='2023-12-31',frequency='daily',panel=False)

# %% [markdown]
# index  date  stock  price

# %%
df
# Out:
#            time         code      ...             volume         money
# 0    2014-01-02  000300.XSHG      ...       4.519429e+09  4.901221e+10
# 1    2014-01-03  000300.XSHG      ...       5.978264e+09  5.773971e+10
# 2    2014-01-06  000300.XSHG      ...       6.630040e+09  5.997936e+10
# 3    2014-01-07  000300.XSHG      ...       4.375310e+09  4.256565e+10
# 4    2014-01-08  000300.XSHG      ...       5.134885e+09  5.069149e+10
# 5    2014-01-09  000300.XSHG      ...       5.598704e+09  5.439949e+10
# 6    2014-01-10  000300.XSHG      ...       5.416929e+09  4.757231e+10
# 7    2014-01-13  000300.XSHG      ...       5.012277e+09  4.612300e+10
# 8    2014-01-14  000300.XSHG      ...       5.404995e+09  4.678510e+10
# 9    2014-01-15  000300.XSHG      ...       4.896240e+09  4.575591e+10
# 10   2014-01-16  000300.XSHG      ...       5.229890e+09  4.984278e+10
# 11   2014-01-17  000300.XSHG      ...       5.027316e+09  4.626816e+10
# ...

# %%
df.to_csv('index_file.csv', index=False)
